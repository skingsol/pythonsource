# %%
# 크롤링 라이브러리
# requests, BeautipleSoup, Selenium, scrapy....

# 파이썬 라이브러리 사용할 수도 있으나 외부 라이브러리를 주로 사용함

# requests : 특정 url 에서 정보를 가져오기 쉽게 도와주는 라이브러리

# %%
import requests

urls = ["https://www.python.org/","https://www.naver.com/"]


name = "robots.txt"

for url in urls:
    print(url+name)
    robots = requests.get(url+name)   # 
    print(robots.text)
# Out:
# https://www.python.org/robots.txt
# # Directions for robots.  See this URL:
# # http://www.robotstxt.org/robotstxt.html
# # for a description of the file format.
#
# User-agent: HTTrack
# User-agent: puf
# User-agent: MSIECrawler
# Disallow: /
#
# # The Krugle web crawler (though based on Nutch) is OK.
# User-agent: Krugle
# Allow: /
# Disallow: /~guido/orlijn/
# Disallow: /webstats/
#
# # No one should be crawling us with Nutch.
# User-agent: Nutch
# Disallow: /
#
# # Hide old versions of the documentation and various large sets of files.
# User-agent: *
# Disallow: /~guido/orlijn/
# Disallow: /webstats/
#
# https://www.naver.com/robots.txt
# User-agent: *
# Disallow: /
# Allow : /$

# %%
import urllib.request as req

url = "https://google.com"

save_file = "./google.html"

try:
    file1, header1 = req.urlretrieve(url,save_file)
except Exception as e:
    print(e)
else:
    print(header1)
    print(file1)
    print("성공")
# Out:
# Date: Thu, 06 Jul 2023 07:18:12 GMT
# Expires: -1
# Cache-Control: private, max-age=0
# Content-Type: text/html; charset=ISO-8859-1
# Content-Security-Policy-Report-Only: object-src 'none';base-uri 'self';script-src 'nonce-CjLOgggkbGL8kg6WegoUGg' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Server: gws
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Set-Cookie: 1P_JAR=2023-07-06-07; expires=Sat, 05-Aug-2023 07:18:12 GMT; path=/; domain=.google.com; Secure
# Set-Cookie: AEC=Ad49MVFxwaARNltBreCf0NIp8tQld0aHhq-k7SsUNZzThMo30BHCGElBxLA; expires=Tue, 02-Jan-2024 07:18:12 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax
# Set-Cookie: NID=511=GHuvVUJ_3-2xbRvlFLPHzzrZpQ9xAsoxGDXoSOqduUha4gLc7NHE09iWbmWNk4PY1M9JxKG6ykKlxxEdm3xh3Dh1O6pOST5nKn-cLlNCBy7jMF8znVLFEv6Z9dmXXyZeC6y4JPWH2aKUANRGJdtSJSPyjAR4PU5oK3s7padgeds; expires=Fri, 05-Jan-2024 07:18:12 GMT; path=/; domain=.google.com; HttpOnly
# Alt-Svc: h3=":443"; ma=2592000,h3-29=":443"; ma=2592000
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close
# Transfer-Encoding: chunked
#
#
# ./google.html
# 성공

# %% [markdown]
# ##### urlretrieve
#     - 요청하는 url의 정보를 로컬 파일로 저장
#     - 튜플로 반환됨
#     - csv, api 데이터 등 많은 양의 데이터를 한번에 저장할 때 사용

# %%
img_url = "https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzA2MDhfNjgg%2FMDAxNjg2MjA4MDUxNzcz.0LRu-ZEx7KhZqGUGlQzfTOB3gLa1Umikb_ODWH_3Alwg.kY5hTeUSVN59Xc0KCGLjUjTZl4kZooHrws3UYE3TTv4g.JPEG.24sooamc2019%2FGettyImages-1495553264.jpg&type=a340"
html_url = "https://www.naver.com"

# 경로
img_path = "./cat.jpg"
html_path = "./naver.html"

try:
    file1, header1 = req.urlretrieve(img_url,img_path)
    file2, header2 = req.urlretrieve(html_url,html_path)
except Exception as e:
    print(e)
else:
    print("file1 {}".format(file1))
    print("file2 {}".format(file2))
# Out:
# file1 ./cat.jpg
# file2 ./naver.html

# %% [markdown]
# ##### 다운로드는 필요없고 내용만 분석하고 싶을 때
#     - urlopen(), read()

# %%
weather_url = "https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109"

data = req.urlopen(weather_url).read()

text = data.decode("utf-8")
print(text)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2023년 07월 06일 (목)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>서울,경기도 육상 중기예보 - 2023년 07월 06일 (목)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_02.jsp</guid>
# <description>
# 	<header>
# 		<title>서울,경기도 육상중기예보</title>
# 		<tm>202307060600</tm>
# 		<wf><![CDATA[○ (강수) 9일(일)~11일(화)과 14일(금)은 소나기가, 15일(토)은 비가 내리는 곳이 있겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~25도로 평년(최저기온 20~22도)보다 높겠고, 낮 기온은 26~31도로 평년(최고기온 27~30도)과 비슷하겠습니다.<br />○ (해상) 서해중부해상의 물결은 12일(수)~14일(금) 1.5~3.0m로 높게 일겠고, 그 밖의 날은 0.5~2.0m로 일겠습니다.<br />○ (주말전망) 8일(토)과 9일(일)은 대체로 흐리겠고, 9일은 소나기가 내리는 곳이 있겠습니다. 아침 기온은 21~24도, 낮 기온은 26~31도가 되겠습니다.<br /><br />* 우리나라 주변 기압계 변화에 따라 날씨 변동성이 큰 가운데, 비나 소나기가 내리는 지역과 시점이 변경될 가능성이 있겠으니 앞으로 발표되는 예보와 기상정보를 참고하기 바랍니다.]]></wf>
# 	</header>
# 	<body>
#
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>서울</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>인천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>수원</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>파주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>이천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>평택</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>백령도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>21</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>20</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>과천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>광명</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>강화</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>김포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>시흥</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>안산</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>부천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>의정부</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>고양</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>양주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>동두천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# ...
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>군포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>안성</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>용인</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>광주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>여주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
#
# 	</body>
# </description>
# </item>
# </channel>
# </rss>

# %%
url = "https://www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&xfrom=main^gnb"


try:
    res = req.urlopen(url)
    contents = res.read().decode('euc-kr')
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents[:4000])
# Out:
# Date: Thu, 06 Jul 2023 07:55:25 GMT
# Content-Type: text/html;charset=EUC-KR
# Set-Cookie: JSESSIONID=AC3F3510691DAE87545A443E63C2AC79.Tomcat; Path=/; HttpOnly
# Vary: Accept-Encoding,User-Agent
# Access-Control-Allow-Credentials: true
# Transfer-Encoding: chunked
# Connection: close
# Server: Apache
#
#
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
#
#
#
# <html lang="ko">
# <head>
#
# <title>11번가 베스트 | 11번가</title>
# <meta name="Title" content="11번가 베스트 | 11번가">
# <meta name="Description" content=" 베스트! 다른 사람들은 지금 뭘 살까? 11번가 추천하는 실시간  베스트 아이템 순위!">
# <meta name="Keywords" content=" | 11번가">
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <link rel="canonical" href="//www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&xfrom=main^gnb"/><link rel="alternate" media="only screen and (max-width: 640px)" href="//m.11st.co.kr/page/main/rank"/>
#
#
#
# <script type="text/javascript" src="//c.011st.com/html/experiment/experimentMetaInfo.js"></script>
#
# <script type="text/javascript" src="//c.011st.com/js/plab/plab-web-sdk-0.9.1.min.js"></script>
#
# <script>
#
#     var plabPageKey = '/best200/category';
#     try{
#
#         var params = {
#             projectKey : "11st_web",
#             domain : "11st.co.kr"
#         };
#         plab.initBy(params, experimentMetaInfo);
#
#     }catch (e) { console.log(e) };
#
#
# </script>
#
# <script type="text/javascript">
# 	!function(f,b,e,v,n,t,s) {if(f.fbq)return;n=f.fbq=function(){n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}; if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0'; n.queue=[];t=b.createElement(e);t.async=!0; t.src=v;s=b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t,s)}(window, document,'script', 'https://connect.facebook.net/en_US/fbevents.js');
# 	try {
# 		fbq('init', '2299486926950990');
# 		fbq('track', 'PageView');
# 	} catch (e) {
# 		console.error(e);
# 	}
# </script>
# <noscript>
# 	<img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=2299486926950990&ev=PageView&noscript=1"/>
# </noscript>
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-876562370"></script>
# <script>
# 	try{
# 		window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments);}
# 		gtag('js', new Date());
# 		gtag('config', 'AW-876562370');
# 	} catch(e) {}
# </script>
#
#
# <script type="text/javascript">
#
#
# 	// Global Var
# 	var _IMG_PATH_  = "//s.011st.com";
# 	var _UPLOAD_IMG_PATH_  = "http://image.11st.co.kr";
# 	var _SSL_UPLOAD_IMG_PATH_ = "https://www.11st.co.kr/is";
# 	var _ACTION_CONTEXT_  = "";
# 	var _FILE_UPLOAD_PATH_ = "http://image.11st.co.kr";
# 	var _GNB_CONTEXT_PATH_ = "//www.11st.co.kr";
# 	var _ACTION_CONTEXT_URL_ = "http://www.11st.co.kr";
# 	var _SSL_ACTION_CONTEXT_URL_ = "https://www.11st.co.kr";
# 	var _SSL_IMG_PATH_ = "//s.011st.com";
# 	var _GLOBAL_CONTEXT_PATH_ = "http://globalshopping.11st.co.kr";
# 	var _BEAUTY_CONTEXT_PATH_ = "http://beauty.11st.co.kr";
# 	var _SOHO_CONTEXT_PATH_ = "http://soho.11st.co.kr";
# 	var _JS_PATH_ = "//c.011st.com";
# 	var _SSL_JS_PATH_ = "//c.011st.com";
#
# 	var _GNB_LOGIN_URL_ = "https://login.11st.co.kr/login/Login.tmall";
# 	var _GNB_LOGOUT_URL_ = "https://login.11st.co.kr/login/Logout.tmall";
# 	var _PRODUCT_DETAIL_URL_ = "https://www.11st.co.kr/product/SellerProductDetail.tmall?method=getSellerProductDetail&prdNo=";
#
# 	var _ENJOY_SEARCH_VAR_ = "NONE";
# 	var _ENJOY_SEARCH_KEY_YN_ = "N";
#
# 	var _SELLER_SHOP_DOMAIN_ = "https://shop.11st.co.kr";
#
# 	// 변경 권고
# 	var _CSS_URL_			= "//c.011st.com";
# 	var _SSL_CSS_URL_		= "//c.011st.com";
# 	var _IMG_URL_			= "//s.011st.com";
# 	var _SSL_IMG_URL_		= "//s.011st.com";
# 	var _UPLOAD_URL_		= "http://i.011st.com";
# 	var _SSL_UPLOAD_URL_	= "https://i.011st.com";
#
# 	var _LOGIN_TARGET_URL_ 	= "https://login.11st.co.kr";
#
# 	// TZONE Var
# 	var _TZONE_URL_			= "http://skt.11st.co.kr";
# 	var _TZONE_URL_HOME_	= "http://skt.11st.co.kr/html/tzone/tZoneMain.html";
# 	var _SELLER_URL_		= "http://seller.11st.co.kr";
# 	var _SOFFICE_URL_		= "http://soffice.11st.co.kr";
# 	var _DS_URL_			= "http://ds.11st.co.kr";
# 	var _MY11ST_URL_		= "http://buy.11st.co.kr/order/myTmall.tmall?method=getMyTmallMain";
# 	var _SHOPPINGCART_URL_ 	= "http://buy.11st.co.kr/cart/CartAction.tmall?method=getCartList";
# 	var _MYSELL_U

# %%
# 네이버 뉴스 가져오기

news_url = "https://n.news.naver.com/mnews/article/421/0006910686?sid=102"

try:
    res = req.urlopen(news_url)
    contents = res.read().decode('utf-8')
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents[:4000])
# Out:
# Content-Type: text/html; charset=utf-8
# x-content-type-options: nosniff
# x-xss-protection: 1; mode=block
# x-frame-options: DENY
# referrer-policy: unsafe-url
# Server: nfront
# Vary: Accept-Encoding
# Cache-Control: no-cache, no-store, must-revalidate
# Expires: Thu, 06 Jul 2023 08:04:13 GMT
# Date: Thu, 06 Jul 2023 08:04:13 GMT
# Transfer-Encoding: chunked
# Connection: close
# Connection: Transfer-Encoding
# Set-Cookie: N_SES=162bbf9d-a013-406c-b88f-757527fdf08f; Max-Age=1800; Path=/; Expires=Thu, 06 Jul 2023 08:34:13 GMT
#
#
# <!doctype html>
# <html lang="ko" data-useragent="Python-urllib/3.11">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<meta property="og:title" content="강남 일대서 만취객 부축해주는 척 돈 뺏은 30대 남성 구속">
# 		<meta property="og:type" content="article">
# 		<meta property="og:url" content="https://n.news.naver.com/mnews/article/421/0006910686?sid&#x3D;102">
# 		<meta property="og:image" content="https://imgnews.pstatic.net/image/421/2023/07/06/0006910686_001_20230706100129368.jpg?type&#x3D;w800">
# 		<meta property="og:description" content="만취한 취객을 부축해주는 척하며 스마트폰에 강제로 지문을 인식시키는 방식으로 돈을 빼앗아온 30대 남성이 경찰에 붙잡혔다. 서울 강남경찰서는 강도·절도·공갈·컴퓨터사용사기 등의 혐의로 30대 남성 A씨를 구속 수사하">
# 		<meta property="og:article:author" content="뉴스1 | 네이버">
# 		<meta name="twitter:card" content="summary_large_image">
# 		<meta name="twitter:title" content="강남 일대서 만취객 부축해주는 척 돈 뺏은 30대 남성 구속">
# 		<meta name="twitter:site" content="네이버 뉴스">
# 		<meta name="twitter:creator" content="뉴스1">
# 		<meta name="twitter:image" content="https://imgnews.pstatic.net/image/421/2023/07/06/0006910686_001_20230706100129368.jpg?type&#x3D;w800">
# 		<meta name="twitter:description" content="만취한 취객을 부축해주는 척하며 스마트폰에 강제로 지문을 인식시키는 방식으로 돈을 빼앗아온 30대 남성이 경찰에 붙잡혔다. 서울 강남경찰서는 강도·절도·공갈·컴퓨터사용사기 등의 혐의로 30대 남성 A씨를 구속 수사하">
# 		<meta name="napp-site-analysis" content="gdid=08138263_000000000000000006910686,service=news,collection=news,section=102">
# 		<title>강남 일대서 만취객 부축해주는 척 돈 뺏은 30대 남성 구속</title>
# 			<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20230629/news.css">
# 			<link rel="shortcut icon" type="image/x-icon" href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" />
# 			<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 			<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />
# 			<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />
# 			<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />
# 			<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 					<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# 		<script>
# 			var g_ssc = nsc = "Mnews.v2";
# 			var g_default_area = "art";
#
# 			var svr = "one-service-r-20230629-230629-152229-5ff864545d-224fr";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "https://news.naver.com";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
# 				isSubscribe: false,
# 				officeId: "421",
# 				articleId: "0006910686",
# 				sectionId : "102",
# 				gdid: "08138263_000000000000000006910686",
# 				type: "1",
# 				sectionInfo: {
# 					firstSection: "102",
# 					secondSection: "249",
# 					thirdSection: "000"
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: true,
# 				isPressHome: true,
# 				name : "뉴스1",
# 				category : "방송/통신사"
# 			};
#
# 			var refererType = "UNKNOWN";
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(

# %%
url = "https://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.xml?key=f5eef3421c602c6cb7ea224104795888&targetDt=20230705"


try:
    res = req.urlopen(url)
    contents = res.read().decode('utf-8')
except Exception as e:
    print(e)
else:
    with open("./movie.txt","w",encoding="utf-8") as f:
        f.write(contents)

# %%
from urllib.parse import urlencode


url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&"

param = {"query":"축구"}

url += urlencode(param)

try:
    res = req.urlopen(url)
    contents = res.read().decode('utf-8')
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents[:4000])
# Out:
# Date: Thu, 06 Jul 2023 08:36:56 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# Vary: Accept-Encoding
# Set-Cookie: page_uid=i6i96sp0Jy0ssTDMzoZssssssIo-367469; path=/; domain=.naver.com
# Set-Cookie: _naver_usersession_=dAcL5ImOR6q5pR1vjefPQw==; path=/; expires=Thu, 06-Jul-23 08:41:56 GMT; domain=.naver.com
# X-Frame-Options: SAMEORIGIN
# X-XSS-Protection: 1; report=/p/er/post/xss
# Cache-Control: no-cache, no-store, must-revalidate, max-age=0
# Pragma: no-cache
# Set-Cookie: nx_ssl=2; Domain=.naver.com; Path=/; Expires=Sat, 05-Aug-2023 08:36:56 GMT;
# Referrer-Policy: unsafe-url
# Vary: Accept-Encoding
# Server: nxg
# Accept-CH: Sec-CH-UA, Sec-CH-UA-Arch, Sec-CH-UA-Bitness, Sec-CH-UA-Full-Version-List, Sec-CH-UA-Mobile, Sec-CH-UA-Model, Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version, Sec-CH-UA-WoW64
#
#
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="축구 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'축구'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'축구'의 네이버 통합검색 결과입니다."> <title>축구 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_230706.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_230629.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement('script'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName('head')[0].appendChild(scrs[script].domscript); }; })() ; var nx_js_defer_load = (function() { var info = {} ; return function(scrname, callback, t) { var nx_load_once = (function() { return function(scrname) { if (info[scrname].t > 0) setTimeout(function() { _nx_js_load(scrname, info[scrname].callback) ; }, t) ; else _nx_js_load(scrname, info[scrname].callback) ; } ; })(); if (t < 0) t = 0 ; if (info[scrname]) { n = info[scrname].length; for (var i = 0; i < n; i++) { if (info[scrname][i] == callback) return ; } if (t < info[scrname].t) info[scrname].t = t ; } else { info[scrname] = {} ; info[scrname].callback = [] ; info[scrname].t = t ; jindo.$Fn(function() { nx_load_once(scrname) ; }).attach(window, "load") ; } info[scrname].callback.push(callback) ; }; })(); function nx_js_lazyload(scripts, onload, is_serial) { if (!(scripts instanceof Array)) { scripts = [scripts]; } if (is_serial) { function load_next() { if (scripts.length == 0) { onload(); return; } _nx_js_load( scripts.shift(), load_next ) ; } load_next(); } else { var load_check = function() { var num_js = scripts.length; return function() {

# %%
# fake-useragent : useragent 생성
# 파이썬으로 크롤링 시 상대 서버는 파이썬 프로그램으로 요청이 들어온다는 걸 알게 됨
# 요청을 브라우저로 하고 있다고 속여내는 방법

# %%
from fake_useragent import UserAgent

userAgent = UserAgent()

print(userAgent.ie)
print(userAgent.chrome)
print(userAgent.random)
# Out:
# Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Win64; x64; Trident/5.0
# Mozilla/5.0 (X11; U; Linux i686; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/4.0.211.2 Safari/532.0
# Mozilla/5.0 (X11) AppleWebKit/62.41 (KHTML, like Gecko) Edge/17.10859 Safari/452.6

# %%
from fake_useragent import UserAgent
import urllib.request as req 


try:
    userAgent = UserAgent()

    url = "https://v.daum.net/v/20230707060034563"

    headers = {
        "user-agent":userAgent.random
    }

    request_url = req.Request(url,headers=headers)
    # request_url = req.Request(url)  # 'Python-urllib/3.11'
    info = req.urlopen(request_url)
    res = info.read().decode("utf-8")
except Exception as e:
    print(e)
else:
    print("response headers {}".format(info.info()))
    print("request headers {}".format(request_url.header_items()))
# Out:
# response headers Date: Fri, 07 Jul 2023 00:55:47 GMT
# Content-Type: text/html;charset=UTF-8
# Content-Length: 95546
# Connection: close
# Strict-Transport-Security: max-age=15724800; includeSubDomains
#
#
# request headers [('Host', 'v.daum.net'), ('User-agent', 'Python-urllib/3.11')]

# %%
from fake_useragent import UserAgent
import urllib.request as req 
import json
import csv

kosdaq = []

try:
    userAgent = UserAgent()

    url = "https://finance.daum.net/api/search/ranks?limit=10"

    headers = {
        "user-agent":userAgent.random,
        "referer" : "https://finance.daum.net/"
    }

    request_url = req.Request(url,headers=headers)    
    info = req.urlopen(request_url)
    res = info.read().decode("utf-8")
except Exception as e:
    print(e)
else:
    # print(res)

    # json => 딕셔너리 
    data = json.loads(res)["data"]

    for item in data:
        print("순위 : {}, 금액 : {}, 회사명 : {}".format(item["rank"],item["tradePrice"],item["name"]))

        kosdaq.append(item)

        with open("./finance.csv","w",newline="") as f:
            output = csv.writer(f)
            # 헤더명 작성
            output.writerow(kosdaq[0].keys())

            for row in kosdaq:
                output.writerow(row.values())
# Out:
# 순위 : 1, 금액 : 50500, 회사명 : 카카오
# 순위 : 2, 금액 : 70400, 회사명 : 삼성전자
# 순위 : 3, 금액 : 80100, 회사명 : 금양
# 순위 : 4, 금액 : 954000, 회사명 : 에코프로
# 순위 : 5, 금액 : 56500, 회사명 : 삼성중공우
# 순위 : 6, 금액 : 3760, 회사명 : 삼부토건
# 순위 : 7, 금액 : 28920, 회사명 : KODEX 2차전지산업
# 순위 : 8, 금액 : 17290, 회사명 : 두산에너빌리티
# 순위 : 9, 금액 : 31385, 회사명 : KODEX 반도체
# 순위 : 10, 금액 : 6140, 회사명 : 시큐센
